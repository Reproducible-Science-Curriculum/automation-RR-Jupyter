# %% [markdown]
# # Demo: Import your functions as a module

# %%
import sys
import os
scriptpath = '/home/ejmctavish/Desktop/carpentries/automation-RR-Jupyter/code'
# Add the directory containing your module to the Python path (must be absolute path)
sys.path.append(scriptpath)
import mystatstest as mystats

# %%
import pylab as plt
import numpy as np

# %%
# Your docstrings now show up as help
help(mystats.calculate_statistic_over_time)
# Out:
# Help on function calculate_statistic_over_time in module mystatstest:
#
# calculate_statistic_over_time(data, category, continent, func, VERBOSE=0)
#     calculate values of a statistic through time
#
#     Args:
#         data: a pandas data frame
#         category: one of the column headers of the data frame (e.g. 'lifeexp')
#         continent: possible value of the continent column of that data frame (e.g. 'asia')
#         func: the funtion to apply to data values (e.g. np.mean)
#
#     Returns:
#         a summary table of value per year.

# %%
help(mystats.read_data)
# Out:
# Help on function read_data in module mystatstest:
#
# read_data(filepath)
#     reads csv file in as pandas data frame
#     Args:
#       filepath: path to file
#     Returns:
#       Pandas data frame
#     Raises:
#       File not found error

# %%
df=mystats.read_data('../data/gapminder_cleaned.csv')

# %%
#use this function to plot life expectancy| through time
continents = df['continent'].unique()
fig, ax = plt.subplots()
for continent in continents:
    output = mystats.calculate_statistic_over_time(df,"lifeexp", continent, np.mean)
    output.plot.line('year', "lifeexp", ax=ax, label=continent)
